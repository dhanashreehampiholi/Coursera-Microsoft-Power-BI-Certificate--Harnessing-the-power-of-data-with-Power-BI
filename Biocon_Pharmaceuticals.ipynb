# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanashreehampiholi/Coursera-Microsoft-Power-BI-Certificate--Harnessing-the-power-of-data-with-Power-BI/blob/main/Biocon_Pharmaceuticals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Import the dataset.
df = pd.read_csv('RFM analysis on Biocon Pharmaceuticals_.csv')
df.head()
# Out:
#    Gender  Age Occupation  Annual income(in lakhs)  Reputation_trust  Quality  \
# 0  Female   22    Student                      2.5                 5        3
# 1  Female   21    Student                     12.0                 4        4
# 2    Male   24   Employee                      7.0                 3        3
# 3    Male   32   Employee                      7.5                 3        3
# 4  Female   22    Student                      1.0                 5        4
#
#    Preference  Expectations  Suggestion  Information_updates Recommendation  \
# 0           4             4           4                    4            Yes
# 1           3             4           4                    3            Yes
# 2           3             3           3                    3             No
# 3           3             3           2                    2            Yes
# 4           4             4           4                    4            Yes
#
#    Spendings
# 0       1000
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'Annual income(in lakhs)',
#        'Reputation_trust', 'Quality', 'Preference', 'Expectations',
#        'Suggestion', 'Information_updates', 'Recommendation', 'Spendings'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   49 non-null     object
#  1   Age                      49 non-null     int64
#  2   Occupation               49 non-null     object
#  3   Annual income(in lakhs)  49 non-null     float64
#  4   Reputation_trust         49 non-null     int64
#  5   Quality                  49 non-null     int64
#  6   Preference               49 non-null     int64
#  7   Expectations             49 non-null     int64
#  8   Suggestion               49 non-null     int64
#  9   Information_updates      49 non-null     int64
#  10  Recommendation           49 non-null     object
#  11  Spendings                49 non-null     int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 4.7+ KB

# %%
sns.pairplot(df[['Age','Annual income(in lakhs)',
       'Reputation_trust', 'Quality', 'Preference', 'Expectations',
       'Suggestion', 'Information_updates','Spendings']])
plt.title('Pairwaise Plot')
plt.show()

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
frequency_table = df['Gender'].value_counts()
print(frequency_table)
# Out:
# Female    26
# Male      23
# Name: Gender, dtype: int64

# %%
frequency_table = df['Occupation'].value_counts()
print(frequency_table)
# Out:
# Student     35
# Employee    14
# Name: Occupation, dtype: int64

# %%
sns.countplot(x='Occupation',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
frequency_table = df['Recommendation'].value_counts()
print(frequency_table)
# Out:
# Yes    36
# No     13
# Name: Recommendation, dtype: int64

# %%
sns.countplot(x='Recommendation',data=df)
# Out:
# <Axes: xlabel='Recommendation', ylabel='count'>

# %%
df.corr()
# Out:
# <ipython-input-53-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                               Age  Annual income(in lakhs)  Reputation_trust  \
# Age                      1.000000                 0.154517         -0.458792
# Annual income(in lakhs)  0.154517                 1.000000         -0.369622
# Reputation_trust        -0.458792                -0.369622          1.000000
# Quality                 -0.638076                -0.015736          0.641502
# Preference              -0.459111                -0.227038          0.805610
# Expectations            -0.534129                -0.114548          0.812283
# Suggestion              -0.417277                -0.433868          0.623038
# Information_updates     -0.277424                -0.572554          0.547560
# ...

# %%
cor_matrix=df.corr()
sns.heatmap(cor_matrix,cmap='Blues')
# Out:
# <ipython-input-54-14495e7a01e3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_matrix=df.corr()
# <Axes: >

# %%
pd.crosstab(index=df['Gender'],columns=df['Occupation'])  #Gives cross tab
# Out:
# Occupation  Employee  Student
# Gender
# Female             5       21
# Male               9       14

# %%
pd.crosstab(index=df['Gender'],columns=df['Occupation'],margins=True,normalize=True)  # Marginal probability: margin is used to return the row and column total, normalize is used to express in percentage
# Out:
# Occupation  Employee   Student       All
# Gender
# Female      0.102041  0.428571  0.530612
# Male        0.183673  0.285714  0.469388
# All         0.285714  0.714286  1.000000

# %%
pd.crosstab(index=df['Gender'],columns=df['Occupation'],margins=True,normalize='index') #normalize = 'index' gives conditional probability, index becomes denominator
# Out:
# Occupation  Employee   Student
# Gender
# Female      0.192308  0.807692
# Male        0.391304  0.608696
# All         0.285714  0.714286

# %%
pd.crosstab(index=df['Gender'],columns=df['Occupation'],margins=True,normalize='columns') #normalize = 'columns' gives joint probability, column becomes denominator
# Out:
# Occupation  Employee  Student       All
# Gender
# Female      0.357143      0.6  0.530612
# Male        0.642857      0.4  0.469388

# %%
#Train test split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
df=pd.get_dummies(df,columns=['Gender'],drop_first = True)

# %%
df.head()
# Out:
#    Age Occupation  Annual income(in lakhs)  Reputation_trust  Quality  \
# 0   22    Student                      2.5                 5        3
# 1   21    Student                     12.0                 4        4
# 2   24   Employee                      7.0                 3        3
# 3   32   Employee                      7.5                 3        3
# 4   22    Student                      1.0                 5        4
#
#    Preference  Expectations  Suggestion  Information_updates Recommendation  \
# 0           4             4           4                    4            Yes
# 1           3             4           4                    3            Yes
# 2           3             3           3                    3             No
# 3           3             3           2                    2            Yes
# 4           4             4           4                    4            Yes
#
#    Spendings  Gender_Male
# 0       1000            0
# 1       1000            0
# ...

# %%
df=pd.get_dummies(df,columns=['Occupation'],drop_first=True)

# %%
df.head()
# Out:
#    Age  Annual income(in lakhs)  Reputation_trust  Quality  Preference  \
# 0   22                      2.5                 5        3           4
# 1   21                     12.0                 4        4           3
# 2   24                      7.0                 3        3           3
# 3   32                      7.5                 3        3           3
# 4   22                      1.0                 5        4           4
#
#    Expectations  Suggestion  Information_updates Recommendation  Spendings  \
# 0             4           4                    4            Yes       1000
# 1             4           4                    3            Yes       1000
# 2             3           3                    3             No          0
# 3             3           2                    2            Yes          0
# 4             4           4                    4            Yes        500
#
#    Gender_Male  Occupation_Student
# 0            0                   1
# ...

# %%
label_encoder=LabelEncoder()
df['Recommendation']=label_encoder.fit_transform(df['Recommendation'])

# %%
df.head()
# Out:
#      Age  Annual income(in lakhs)  Reputation_trust  Quality  Preference  \
# 0  18-24                      2.5                 5        3           4
# 1  18-24                     12.0                 4        4           3
# 2  18-24                      7.0                 3        3           3
# 3  25-34                      7.5                 3        3           3
# 4  18-24                      1.0                 5        4           4
#
#    Expectations  Suggestion  Information_updates  Recommendation  Spendings  \
# 0             4           4                    4               1       1000
# 1             4           4                    3               1       1000
# 2             3           3                    3               0          0
# 3             3           2                    2               1          0
# 4             4           4                    4               1        500
#
#    Gender_Male  Occupation_Student
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Annual income(in lakhs)', 'Reputation_trust', 'Quality',
#        'Preference', 'Expectations', 'Suggestion', 'Information_updates',
#        'Recommendation', 'Spendings', 'Gender_Male', 'Occupation_Student'],
#       dtype='object')

# %%
sc= StandardScaler()
num_cols=['Annual income(in lakhs)', 'Reputation_trust', 'Quality',
       'Preference', 'Expectations', 'Suggestion', 'Information_updates', 'Spendings']
df[num_cols]=sc.fit_transform(df[num_cols])

# %%
df.head()
# Out:
#    Age  Annual income(in lakhs)  Reputation_trust   Quality  Preference  \
# 0   22                -0.378952          1.142264 -0.881591    0.260998
# 1   21                 2.734946         -0.101535  0.558341   -1.017892
# 2   24                 1.096052         -1.345334 -0.881591   -1.017892
# 3   32                 1.259941         -1.345334 -0.881591   -1.017892
# 4   22                -0.870620          1.142264  0.558341    0.260998
#
#    Expectations  Suggestion  Information_updates  Recommendation  Spendings  \
# 0      0.373544    0.427205             0.739704               1   0.941063
# 1      0.373544    0.427205            -0.239904               1   0.941063
# 2     -1.151760   -0.524297            -0.239904               0  -1.037996
# 3     -1.151760   -1.475798            -1.219512               1  -1.037996
# 4      0.373544    0.427205             0.739704               1  -0.048467
#
#    Gender_Male  Occupation_Student
# 0            0                   1
# ...

# %%
X=df.drop(['Recommendation'],axis=1)
y=df['Recommendation']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=3)

# %%
df.head()
# Out:
#    Age  Annual income(in lakhs)  Reputation_trust   Quality  Preference  \
# 0   22                -0.378952          1.142264 -0.881591    0.260998
# 1   21                 2.734946         -0.101535  0.558341   -1.017892
# 2   24                 1.096052         -1.345334 -0.881591   -1.017892
# 3   32                 1.259941         -1.345334 -0.881591   -1.017892
# 4   22                -0.870620          1.142264  0.558341    0.260998
#
#    Expectations  Suggestion  Information_updates  Recommendation  Spendings  \
# 0      0.373544    0.427205             0.739704               1   0.941063
# 1      0.373544    0.427205            -0.239904               1   0.941063
# 2     -1.151760   -0.524297            -0.239904               0  -1.037996
# 3     -1.151760   -1.475798            -1.219512               1  -1.037996
# 4      0.373544    0.427205             0.739704               1  -0.048467
#
#    Gender_Male  Occupation_Student
# 0            0                   1
# ...

# %% [markdown]
# ### **Model Building**

# %%
#importing the libraries for model building
from sklearn.linear_model import LogisticRegression  #importing LR
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
#Creating an instance for Logistic Regression
lr_model = LogisticRegression()  #Now fitting the model
lr_model.fit(X_train,y_train)
lr_pred=lr_model.predict(X_test)

print(confusion_matrix(y_test,lr_pred)) #gives true positive and true negative
print(classification_report(y_test,lr_pred))   #gives sensitivity
print(accuracy_score(y_test,lr_pred))  #gives precision

#our interest lies in output = 1
#recall is sensitivity
# Out:
# [[1 2]
#  [0 7]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         3
#            1       0.78      1.00      0.88         7
#
#     accuracy                           0.80        10
#    macro avg       0.89      0.67      0.69        10
# weighted avg       0.84      0.80      0.76        10
#
# 0.8

# %%
knn_model = KNeighborsClassifier(n_neighbors=2)  # n_neighbors = 2 is k=2
#we choose k=2 because accuracy is highest at k=2
knn_model.fit(X_train,y_train)
knn_pred=knn_model.predict(X_test)


print(confusion_matrix(y_test,knn_pred))
print(classification_report(y_test,knn_pred))
print(accuracy_score(y_test,knn_pred))
# Out:
# [[2 1]
#  [0 7]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         3
#            1       0.88      1.00      0.93         7
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.83      0.87        10
# weighted avg       0.91      0.90      0.89        10
#
# 0.9

# %%
tree_model=DecisionTreeClassifier(criterion = 'gini') # or entropy
tree_model.fit(X_train,y_train)
tree_pred=tree_model.predict(X_test)

print(confusion_matrix(y_test,tree_pred))
print(classification_report(y_test,tree_pred))
print(accuracy_score(y_test,tree_pred))
# Out:
# [[2 1]
#  [0 7]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         3
#            1       0.88      1.00      0.93         7
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.83      0.87        10
# weighted avg       0.91      0.90      0.89        10
#
# 0.9

# %%
rf_model=RandomForestClassifier(criterion = 'gini', n_estimators=100,min_impurity_decrease=0.02) # It is an ensemble method
rf_model.fit(X_train,y_train)
rf_pred=rf_model.predict(X_test)

print(confusion_matrix(y_test,rf_pred))
print(classification_report(y_test,rf_pred))
print(accuracy_score(y_test,rf_pred))
# Out:
# [[0 3]
#  [0 7]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.70      1.00      0.82         7
#
#     accuracy                           0.70        10
#    macro avg       0.35      0.50      0.41        10
# weighted avg       0.49      0.70      0.58        10
#
# 0.7
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
NB_model=GaussianNB() # It is a bayes model
NB_model.fit(X_train,y_train)
NB_pred=rf_model.predict(X_test)

print(confusion_matrix(y_test,NB_pred))
print(classification_report(y_test,NB_pred))
print(accuracy_score(y_test,NB_pred))
# Out:
# [[0 3]
#  [0 7]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.70      1.00      0.82         7
#
#     accuracy                           0.70        10
#    macro avg       0.35      0.50      0.41        10
# weighted avg       0.49      0.70      0.58        10
#
# 0.7
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
print('MAE=',mean_absolute_error(y,y_pred))
print('MSE=',mean_squared_error(y,y_pred))
print('R2 score=',r2_score(y,y_pred))
# Out:
# MAE= 0.2655266195250451
# MSE= 0.10712844107727926
# R2 score= 0.4503944721654968

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      49 non-null     int64
#  1   Annual income(in lakhs)  49 non-null     float64
#  2   Reputation_trust         49 non-null     float64
#  3   Quality                  49 non-null     float64
#  4   Preference               49 non-null     float64
#  5   Expectations             49 non-null     float64
#  6   Suggestion               49 non-null     float64
#  7   Information_updates      49 non-null     float64
#  8   Recommendation           49 non-null     int64
#  9   Spendings                49 non-null     float64
#  10  Gender_Male              49 non-null     uint8
#  11  Occupation_Student       49 non-null     uint8
# dtypes: float64(8), int64(2), uint8(2)
# memory usage: 4.0 KB
